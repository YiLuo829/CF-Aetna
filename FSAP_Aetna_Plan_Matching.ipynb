# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/YiLuo/Documents/Python Scripts/FSAPAetna08162.csv", encoding = "ISO-8859-1")
df.head()
# Out:
#    HD  HD01  HD02 HD03                             HD04 HD05  \
# 0  HD    30   NaN  HLT  001+0870176+010+00001+00100+110  EMP
# 1  HD    30   NaN  HLT  001+0870176+010+00001+00200+110  EMP
# 2  HD    30   NaN  HLT  001+0870176+010+00001+00300+110  EMP
# 3  HD    30   NaN  HLT  001+0870176+010+00001+00400+110  EMP
# 4  HD    30   NaN  HLT  001+0870176+010+00001+00500+110  EMP
#
#                          Account Name  \
# 0  FSAP - PPO TRADITIONAL PLAN ACTIVE
# 1  FSAP - PPO TRADITIONAL PLAN ACTIVE
# 2  FSAP - PPO TRADITIONAL PLAN ACTIVE
# 3  FSAP - PPO TRADITIONAL PLAN ACTIVE
# 4  FSAP - PPO TRADITIONAL PLAN ACTIVE
#
#                                          Description
# 0  VIRGINIA - COVERS EMPLOYEES AND DEPENDENTS ELE...
# 1  ALASKA - COVERS EMPLOYEES AND DEPENDENTS ELECT...
# 2  ARIZONA - COVERS EMPLOYEES AND DEPENDENTS ELEC...
# 3  CALIFORNIA - COVERS EMPLOYEES AND DEPENDENTS E...
# 4  COLORADO - COVERS EMPLOYEES AND DEPENDENTS ELE...

# %%
print(df["Account Name"][1])
# Out:
# FSAP - PPO TRADITIONAL PLAN ACTIVE

# %%
Planid=[]
for i in range(0, len(df["Account Name"])):
    if df["Account Name"][i] == "FSAP - PPO TRADITIONAL PLAN ACTIVE":
        Planid.append("31048")
    elif df["Account Name"][i] == "PETA - PPO TRADITIONAL PLAN ACTIVE":
        Planid.append("31023")
    elif df["Account Name"][i] == "BLANK - PPO TRADITIONAL PLAN ACTIVE":
        Planid.append("31023")
    elif df["Account Name"][i] == "HYBRID HRA - FSAP PPO STANDARD HRA PLAN ACTIVE":
        Planid.append("31047")
    elif df["Account Name"][i] == "HYBRID HRA - PETA PPO STANDARD HRA PLAN ACTIVE":
        Planid.append("31022")
    elif df["Account Name"][i] == "HYBRID HRA - BLANK PPO STANDARD HRA PLAN ACTIVE":
        Planid.append("31022")
    elif df["Account Name"][i] == "FSAP - PPO SAVINGS PLAN ACTIVE":
        Planid.append("31046")
    elif df["Account Name"][i] == "PETA - PPO SAVINGS PLAN ACTIVE":
        Planid.append("31021")
    elif df["Account Name"][i] == "BLANK - PPO SAVINGS PLAN ACTIVE":
        Planid.append("31021")
    elif df["Account Name"][i] == "FSAP - PPO STANDARD DENTAL ACTIVE":
        Planid.append("31050")
    elif df["Account Name"][i] == "PETA - PPO STANDARD DENTAL ACTIVE":
        Planid.append("31024")
    elif df["Account Name"][i] == "BLANK - PPO STANDARD DENTAL ACTIVE":
        Planid.append("31024")
    elif df["Account Name"][i] == "FSAP - PPO ORTHODONTIA DENTAL ACTIVE":
        Planid.append("31051")
    elif df["Account Name"][i] == "PETA - PPO ORTHODONTIA DENTAL ACTIVE":
        Planid.append("31025")
    elif df["Account Name"][i] == "BLANK - PPO ORTHODONTIA DENTAL ACTIVE":
        Planid.append("31025")
    elif df["Account Name"][i] == "FSAP - AETNA VISION PREFERRED ACTIVE":
        Planid.append("31052")
    elif df["Account Name"][i] == "PETA- AETNA VISION PREFERRED ACTIVE":
        Planid.append("31026")
    elif df["Account Name"][i] == "BLANK - AETNA VISION PREFERRED ACTIVE":
        Planid.append("31026")
    else:
        Planid.append("missing")
print(Planid)
len(Planid)
# Out:
# ['31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31048', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31023', '31047', '31047', '31047', '31047', '31047', '31047', '31047', '31047', '31047', '31047', '31047', '31047'
# ...

# %%
## Check which Planid is missing
for i in range(0, len(Planid)):
    if Planid[i] == "missing":
        print(i)
        print(df["Account Name"][i])

# %%
## be careful. state name may be misspelled Oregan-Organ-Oregon, Arizona-Airzona, District-Distric
State=[]
for i in range(0, len(df["Description"])):
    if "WEST VIRGINIA" in df["Description"][i]:
        State.append("WV")
    elif "ALASKA" in df["Description"][i]:
        State.append("AK")
    elif "ARIZONA" in df["Description"][i]:
        State.append("AZ")
    elif "AIRZONA" in df["Description"][i]:
        State.append("AZ")
    elif "CALIFORNIA" in df["Description"][i]:
        State.append("CA")
    elif "COLORADO" in df["Description"][i]:
        State.append("CO")
    elif "CONNECTICUT" in df["Description"][i]:
        State.append("CT")
    elif "DISTRIC OF COLUMBIA" in df["Description"][i]:
        State.append("DC")
    elif "DISTRICT OF COLUMBIA" in df["Description"][i]:
        State.append("DC")
    elif "FLORIDA" in df["Description"][i]:
        State.append("FL")
    elif "GEORGIA" in df["Description"][i]:
        State.append("GA")
    elif "ILLINOIS" in df["Description"][i]:
        State.append("IL")
    elif "KANSAS" in df["Description"][i]:
        State.append("KS")
    elif "MARYLAND" in df["Description"][i]:
        State.append("MD")
    elif "MASSACHUSETTS" in df["Description"][i]:
        State.append("MA")
    elif "MICHIGAN" in df["Description"][i]:
        State.append("MI")
    elif "MISSOURI" in df["Description"][i]:
        State.append("MO")
    elif "NEW HAMPSHIRE" in df["Description"][i]:
        State.append("NH")
    elif "NEW JERSEY" in df["Description"][i]:
        State.append("NJ")
    elif "NEW MEXICO" in df["Description"][i]:
        State.append("NM")
    elif "NEW YORK" in df["Description"][i]:
        State.append("NY")
    elif "NORTH CAROLINA" in df["Description"][i]:
        State.append("NC")
    elif "OHIO" in df["Description"][i]:
        State.append("OH")
    elif "OREGON" in df["Description"][i]:
        State.append("OR")
    elif "ORGAN" in df["Description"][i]:
        State.append("OR")
    elif "OREGAN" in df["Description"][i]:
        State.append("OR")
    elif "PENNSYLVANIA" in df["Description"][i]:
        State.append("PA")
    elif "SOUTH CAROLINA" in df["Description"][i]:
        State.append("SC")
    elif "TENNESSEE" in df["Description"][i]:
        State.append("TN")
    elif "TEXAS" in df["Description"][i]:
        State.append("TX")
    elif "UTAH" in df["Description"][i]:
        State.append("UT")
    elif "VERMONT" in df["Description"][i]:
        State.append("VT")
    elif "WASHINGTON" in df["Description"][i]:
        State.append("WA")
    elif "IOWA" in df["Description"][i]:
        State.append("IA")
    elif "VIRGINIA" in df["Description"][i]:
        State.append("VA")
    elif "LOUISIANA" in df["Description"][i]:
        State.append("LA")
    elif "NEVADA" in df["Description"][i]:
        State.append("NV")
    elif "WISCONSIN" in df["Description"][i]:
        State.append("WI")
    elif "HAWAII" in df["Description"][i]:
        State.append("HI")
    else:
        State.append("missing")
print(State)
len(State)
# Out:
# ['VA', 'AK', 'AZ', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'IL', 'KS', 'MD', 'MA', 'MI', 'MO', 'NH', 'NJ', 'NM', 'NY', 'NC', 'OH', 'OR', 'PA', 'SC', 'TN', 'TX', 'UT', 'VT', 'WA', 'WV', 'LA', 'NV', 'WI', 'VA', 'AK', 'AZ', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'IL', 'KS', 'MD', 'MA', 'MI', 'MO', 'NH', 'NJ', 'NM', 'NY', 'NC', 'OH', 'OR', 'PA', 'SC', 'TN', 'TX', 'UT', 'VT', 'WA', 'WV', 'LA', 'NV', 'WI', 'VA', 'AK', 'AZ', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'IL', 'KS', 'MD', 'MA', 'MI', 'MO', 'NH', 'NJ', 'NM', 'NY', 'NC', 'OH', 'OR', 'PA', 'SC', 'TN', 'TX', 'UT', 'VT', 'WA', 'WV', 'LA', 'NV', 'WI', 'VA', 'AK', 'AZ', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'IL', 'KS', 'MD', 'MA', 'MI', 'MO', 'NH', 'NJ', 'NM', 'NY', 'NC', 'OH', 'OR', 'PA', 'SC', 'TN', 'TX', 'UT', 'VT', 'WA', 'WV', 'LA', 'NV', 'WI', 'VA', 'AK', 'AZ', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'IL', 'KS', 'MD', 'MA', 'MI', 'MO', 'NH', 'NJ', 'NM', 'NY', 'NC', 'OH', 'OR', 'PA', 'SC', 'TN', 'TX', 'UT', 'VT', 'WA', 'WV', 'LA', 'NV', 'WI', 'VA', '
# ...

# %%
## Check which state is missing
for j in range(0, len(State)):
    if State[j] == "missing":
        print(j)
        print(df["Description"][j])

# %%
from collections import Counter
Counter(State)
# Out:
# Counter({'VA': 21,
#          'AK': 21,
#          'AZ': 21,
#          'CA': 21,
#          'CO': 21,
#          'CT': 21,
#          'DC': 21,
#          'FL': 21,
#          'GA': 21,
#          'IL': 21,
#          'KS': 21,
#          'MD': 21,
#          'MA': 21,
#          'MI': 21,
#          'MO': 21,
#          'NH': 21,
#          'NJ': 21,
#          'NM': 21,
#          'NY': 21,
#          'NC': 21,
#          'OH': 21,
#          'OR': 21,
#          'PA': 21,
#          'SC': 21,
#          'TN': 21,
#          'TX': 21,
#          'UT': 21,
#          'VT': 21,
#          'WA': 21,
#          'WV': 21,
#          'LA': 21,
#          'NV': 15,
#          'WI': 21,
#          'IA': 9,
#          'HI': 3})

# %%
Planlevel=[]
for k in range(0, len(df["Description"])):
    if (df["Account Name"][k] == "HYBRID HRA - FSAP PPO STANDARD HRA PLAN ACTIVE" or df["Account Name"][k] == "HYBRID HRA - PETA PPO STANDARD HRA PLAN ACTIVE" or df["Account Name"][k] == "HYBRID HRA - BLANK PPO STANDARD HRA PLAN ACTIVE") and "EMPLOYEES ONLY" in df["Description"][k]:
        Planlevel.append('"EE"')
    elif (df["Account Name"][k] == "HYBRID HRA - FSAP PPO STANDARD HRA PLAN ACTIVE" or df["Account Name"][k] == "HYBRID HRA - PETA PPO STANDARD HRA PLAN ACTIVE" or df["Account Name"][k] == "HYBRID HRA - BLANK PPO STANDARD HRA PLAN ACTIVE") and "EMPLOYEES AND DEPENDENTS" in df["Description"][k]:
        Planlevel.append('"EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC"')
    else:
        Planlevel.append('"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ')
print(Planlevel)
len(Planlevel)
# Out:
# ['"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ', '"EE", "EECC", "EED", "EEDCC", "EEDDP
# ...

# %%
from collections import Counter
Counter(Planlevel)
# Out:
# Counter({'"EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC" ': 501,
#          '"EECC", "EED", "EEDCC", "EEDDPCC", "EES", "EESCC"': 99,
#          '"EE"': 99})

# %%
dffinal =pd.DataFrame({'PlanCode': df['HD04'], 'SubsidiaryId': Planid, 'State Abbr': State, 'PlanLevel': Planlevel})

dffinal
# Out:
#                             PlanCode SubsidiaryId State Abbr  \
# 0    001+0870176+010+00001+00100+110        31048         VA
# 1    001+0870176+010+00001+00200+110        31048         AK
# 2    001+0870176+010+00001+00300+110        31048         AZ
# 3    001+0870176+010+00001+00400+110        31048         CA
# 4    001+0870176+010+00001+00500+110        31048         CO
# 5    001+0870176+010+00001+00600+110        31048         CT
# 6    001+0870176+010+00001+00700+110        31048         DC
# 7    001+0870176+010+00001+00800+110        31048         FL
# 8    001+0870176+010+00001+00900+110        31048         GA
# 9    001+0870176+010+00001+01000+110        31048         IL
# 10   001+0870176+010+00001+01100+110        31048         KS
# 11   001+0870176+010+00001+01200+110        31048         MD
# 12   001+0870176+010+00001+01300+110        31048         MA
# 13   001+0870176+010+00001+01400+110        31048         MI
# ...

# %%
writer = pd.ExcelWriter('0904_FSAP_Aetna_Matching.xlsx', engine='xlsxwriter')

dffinal.to_excel(writer, sheet_name='Sheet1')

writer.save()

# %%
import pandas as pd
import pyautogui as pya
import time
import pyperclip

# %%
#excelFilepath = input("Enter the path to your excel file (ex: /Users/jorgealfaro/Downloads/Mappings): ")
#'/Users/jorgealfaro/Downloads/yimappings2.xlsx'
#df = pd.read_excel(excelFilepath, 1, usecols=[0]) #second sheet, first column
#df2 = pd.read_excel(excelFilepath, 1, usecols=[1])

#dflist = df['COLUMN'].tolist() # puts everything under "column" column in a list
#dflist2 = df2['COLUMN2'].tolist()
#print("first column contains: " + str(len(dflist)) + " cells.")
#print("second column contains: " + str(len(dflist2)) + " cells.")

#if (len(dflist) != len(dflist2) ):
    #print("WARNING: column lengths do not match! ")

# %%
dfexample = dffinal.head()
dfexample
# Out:
#                           PlanCode SubsidiaryId State Abbr  \
# 0  001+0870176+010+00001+00100+110        31048         VA
# 1  001+0870176+010+00001+00200+110        31048         AK
# 2  001+0870176+010+00001+00300+110        31048         AZ
# 3  001+0870176+010+00001+00400+110        31048         CA
# 4  001+0870176+010+00001+00500+110        31048         CO
#
#                                            PlanLevel
# 0  "EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES"...
# 1  "EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES"...
# 2  "EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES"...
# 3  "EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES"...
# 4  "EE", "EECC", "EED", "EEDCC", "EEDDPCC", "EES"...

# %%
plancodelist = dfexample["PlanCode"].tolist()
subsiidlist = dfexample["SubsidiaryId"].tolist()
statelist = dfexample["State Abbr"].tolist()
planlevellist = dfexample["PlanLevel"].tolist()
print("first column contains: " + str(len(plancodelist)) + " cells.")
print("second column contains: " + str(len(subsiidlist)) + " cells.")
print("third column contains: " + str(len(statelist)) + " cells.")
print("fourth column contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")
# Out:
# first column contains: 5 cells.
# second column contains: 5 cells.
# third column contains: 5 cells.
# fourth column contains: 5 cells.

# %%
plancodelist = dfexample["PlanCode"].tolist()
subsiidlist = dfexample["SubsidiaryId"].tolist()
statelist = dfexample["State Abbr"].tolist()
planlevellist = dfexample["PlanLevel"].tolist()
print("first column contains: " + str(len(plancodelist)) + " cells.")
print("second column contains: " + str(len(subsiidlist)) + " cells.")
print("third column contains: " + str(len(statelist)) + " cells.")
print("fourth column contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for CODE in plancodelist:
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for CODE in plancodelist: # loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = ")  #copies code into clipboard
	pya.hotkey('ctrl', 'v') # pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + CODE + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if CODE != plancodelist[len(plancodelist)-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# first column contains: 5 cells.
# second column contains: 5 cells.
# third column contains: 5 cells.
# fourth column contains: 5 cells.
# Navigate to first if statement, you have 5 seconds

# %%
### success for 5 records

plancodelist = dfexample["PlanCode"].tolist()
subsiidlist = dfexample["SubsidiaryId"].tolist()
statelist = dfexample["State Abbr"].tolist()
planlevellist = dfexample["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for CODE in plancodelist:
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(0, len(plancodelist)): # loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
    
	#pya.press('tab')
	#pya.typewrite('"' + CODE + '"')
	if k != plancodelist[len(plancodelist)-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 5 cells.
# SubsidiaryId list contains: 5 cells.
# State list contains: 5 cells.
# PlanLevel list contains: 5 cells.
# Navigate to first if statement, you have 5 seconds

# %%
### success for 100 records (0-99)
## employee level
plancodelist = dffinal["PlanCode"].tolist()
subsiidlist = dffinal["SubsidiaryId"].tolist()
statelist = dffinal["State Abbr"].tolist()
planlevellist = dffinal["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for k in range(0, 100):
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(0, 100): # loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if k != plancodelist[100-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 699 cells.
# SubsidiaryId list contains: 699 cells.
# State list contains: 699 cells.
# PlanLevel list contains: 699 cells.
# Navigate to first if statement, you have 5 seconds

# %%
### success for 100 records (100-299) ## employee level

plancodelist = dffinal["PlanCode"].tolist()
subsiidlist = dffinal["SubsidiaryId"].tolist()
statelist = dffinal["State Abbr"].tolist()
planlevellist = dffinal["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for k in range(100, 300):
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(100, 300): # loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if k != plancodelist[300-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 699 cells.
# SubsidiaryId list contains: 699 cells.
# State list contains: 699 cells.
# PlanLevel list contains: 699 cells.
# Navigate to first if statement, you have 5 seconds

# %%
###  (300-499)## employee level

plancodelist = dffinal["PlanCode"].tolist()
subsiidlist = dffinal["SubsidiaryId"].tolist()
statelist = dffinal["State Abbr"].tolist()
planlevellist = dffinal["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for k in range(300, 500):
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(300, 500): # loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if k != plancodelist[499]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 699 cells.
# SubsidiaryId list contains: 699 cells.
# State list contains: 699 cells.
# PlanLevel list contains: 699 cells.
# Navigate to first if statement, you have 5 seconds

# %%
###  (500-699) ## employee level

plancodelist = dffinal["PlanCode"].tolist()
subsiidlist = dffinal["SubsidiaryId"].tolist()
statelist = dffinal["State Abbr"].tolist()
planlevellist = dffinal["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for k in range(500, 700):
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(500, 700): # loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if k != plancodelist[len(plancodelist)-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 699 cells.
# SubsidiaryId list contains: 699 cells.
# State list contains: 699 cells.
# PlanLevel list contains: 699 cells.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-3d53464ffcdc> in <module>()
#      22         #pya.typewrite( "{{SubsidiaryPlanId}} = " )
#      23
# ---> 24         pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
#      25         pya.hotkey('ctrl', 'v')# pastes the code
#      26
#
# IndexError: list index out of range

# %%
###  (0-299) ## dependent level

plancodelist = dffinal["PlanCode"].tolist()
subsiidlist = dffinal["SubsidiaryId"].tolist()
statelist = dffinal["State Abbr"].tolist()
planlevellist = dffinal["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for k in range(0, 300):
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(0, 300): ##loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if k != plancodelist[300-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 699 cells.
# SubsidiaryId list contains: 699 cells.
# State list contains: 699 cells.
# PlanLevel list contains: 699 cells.
# Navigate to first if statement, you have 5 seconds

# %%
###  (300-499) ## dependent level

plancodelist = dffinal["PlanCode"].tolist()
subsiidlist = dffinal["SubsidiaryId"].tolist()
statelist = dffinal["State Abbr"].tolist()
planlevellist = dffinal["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for k in range(300, 500):
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(300, 500): ##loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if k != plancodelist[500-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 699 cells.
# SubsidiaryId list contains: 699 cells.
# State list contains: 699 cells.
# PlanLevel list contains: 699 cells.
# Navigate to first if statement, you have 5 seconds

# %%
###  (500-699) ## dependent level

plancodelist = dffinal["PlanCode"].tolist()
subsiidlist = dffinal["SubsidiaryId"].tolist()
statelist = dffinal["State Abbr"].tolist()
planlevellist = dffinal["PlanLevel"].tolist()
print("PlanCode list contains: " + str(len(plancodelist)) + " cells.")
print("SubsidiaryId list contains: " + str(len(subsiidlist)) + " cells.")
print("State list contains: " + str(len(statelist)) + " cells.")
print("PlanLevel list contains: " + str(len(planlevellist)) + " cells.")
if (len(plancodelist) != len(subsiidlist) != len(statelist) != len(planlevellist) ):
    print("WARNING: column lengths do not match! ")

for k in range(500, len(planlevellist)):
    pya.click(pya.position())
    
for x in range(3): 
    pya.press('tab')

for k in range(500, len(planlevellist)): ##loops through dflist and populates conditionals according to code
	
	#pya.typewrite( "{{SubsidiaryPlanId}} = " )

	pyperclip.copy("{{SubsidiaryPlanId}} = " + subsiidlist[k] + " AND {{Parent_Parent_State}} = " + '"' + statelist[k] + '"' + " AND {{PlanLevel}} in " + '(' + planlevellist[k] + ')')  #copies code into clipboard
	pya.hotkey('ctrl', 'v')# pastes the code 

	pya.press('tab')

	pyperclip.copy('"' + plancodelist[k] + '"') #
	pya.hotkey('ctrl', 'v')
	#pya.typewrite('"' + CODE + '"')

	if k != plancodelist[len(planlevellist)-1]: #if it's not the last code, navigate down to the next conditional
		for x in range(3): pya.press('tab')
            
print("Navigate to first if statement, you have 5 seconds")
time.sleep(10)
# Out:
# PlanCode list contains: 699 cells.
# SubsidiaryId list contains: 699 cells.
# State list contains: 699 cells.
# PlanLevel list contains: 699 cells.
# Navigate to first if statement, you have 5 seconds
